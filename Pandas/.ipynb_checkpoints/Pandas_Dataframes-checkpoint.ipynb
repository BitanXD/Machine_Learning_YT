# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name':['Bitan','Sonia','Pudding'],
    'Age':[23,23,5],
    'City':['Pune','Siliguri','Siliguri']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City
# 0    Bitan   23      Pune
# 1    Sonia   23  Siliguri
# 2  Pudding    5  Siliguri
