# %%
import pandas as pd
import numpy as np
my_list = [10,20,30]
my_labels = ['a','b','c']
my_dict = {1:10,2:20,3:30}
my_arr = np.array([10,20,30])

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, my_labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_arr, my_labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
